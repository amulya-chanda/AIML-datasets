# %% [markdown]
# kaggle link : https://www.kaggle.com/c/santander-customer-transaction-prediction
# This is a binary class classification dataset

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_csv('/users/amulya/Downloads/santander-customer-transaction-prediction/train.csv')
df.info()
nulls = df.isnull()
df['target'].value_counts()
df = df.drop('ID_code',axis = 1)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
#    target    var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266
# 1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338
# 2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155
# 3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428  14.9250
# 4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405  19.2514
#
#     var_8   var_9  var_10   var_11   var_12   var_13  var_14   var_15  \
# 0 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989  14.5691
# 1  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345  13.7003
# 2 -4.9193  5.9525 -0.3249 -11.2648  14.1929   7.3124  7.5244  14.6472
# ...

# %% [markdown]
# 1. checking for null values - no nulls
# 2. target variable count - unbalanced dataset : 0 -179k ,1-21k
# 3. dropping unwanted columns - ID_code
# 4. Cheking for duplicate rows - no duplicates
# 5. how each column is effecting target column
# 6. checking for distribution - skewness
# 7. passing to model - used 3 dense layers (relu,relu,sigmoid)

# %%
df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
duplicates =df.duplicated()
correlation = df.corr()
target_correlation = correlation['target'].sort_values()
print(target_correlation)
# Out:
# var_81    -0.080917
# var_139   -0.074080
# var_12    -0.069489
# var_146   -0.063644
# var_76    -0.061917
# var_174   -0.061669
# var_21    -0.058483
# var_166   -0.057773
# var_80    -0.057609
# var_165   -0.055734
# var_13    -0.055156
# var_148   -0.055011
# var_198   -0.053000
# var_34    -0.052692
# var_115   -0.050174
# var_109   -0.049926
# var_44    -0.049039
# var_169   -0.048382
# var_149   -0.047319
# var_92    -0.046295
# var_154   -0.046106
# var_108   -0.044791
# var_33    -0.044334
# var_192   -0.042858
# var_9     -0.042805
# var_122   -0.042461
# var_123   -0.040291
# var_107   -0.039997
# var_121   -0.039788
# var_86    -0.039126
# var_127   -0.039125
# var_36    -0.038397
# var_75    -0.038081
# var_172   -0.037976
# var_177   -0.036863
# var_87    -0.035860
# var_197   -0.035303
# var_93    -0.035070
# var_56    -0.035000
# var_188   -0.034015
# var_131   -0.032380
# var_186   -0.030421
# var_141   -0.029701
# var_43    -0.028557
# var_104   -0.026605
# ...

# %%
import matplotlib.pyplot as plt
top_positive_correlation = target_correlation.head(21)[1:]  
top_negative_correlation = target_correlation.tail(20)
top_features = pd.concat([top_positive_correlation, top_negative_correlation])

top_features.plot(kind='bar', figsize=(14, 3))
plt.title('Top Features Correlated with Target')
plt.ylabel('Correlation Coefficient')
plt.xlabel('Feature')
plt.show()

# %% [markdown]
# by finding correlation between target column with other columns, we cannot draw anything as for all columns correlation is nearly equal

# %%
constant_features = [
    feat for feat in df.columns if df[feat].std() == 0
]
print(constant_features)
# df.drop(labels=constant_features, axis=1, inplace=True)
# Out:
# []

# %%
import matplotlib.pyplot as plt
import seaborn as sns
features = df.drop(['target'],axis = 1)

def plot_histograms(features, num_features=200):
    # Limit the number of features to plot
    features_to_plot = features.columns[:num_features]
    num_features = len(features_to_plot)
    
    # Determine the number of rows and columns for the subplots
    n_cols = 4
    n_rows = num_features // n_cols + (num_features % n_cols != 0)
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
    axes = axes.flatten()  
    
    for i, feature in enumerate(features_to_plot):
        ax = axes[i]
        df[df['target'] == 0][feature].plot(kind='hist', alpha=0.5, ax=ax, label='Target 0', color='blue')
        df[df['target'] == 1][feature].plot(kind='hist', alpha=0.5, ax=ax, label='Target 1', color='red')
        ax.set_title(f'Histogram of {feature} by Target')
        ax.set_xlabel(feature)
        ax.set_ylabel('Frequency')
        ax.legend()
    
    # Remove any empty subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.show()

# plot_histograms(features, num_features=200)

# %%
skewness = df.select_dtypes(include=['int64', 'float64']).skew()
positive_skewness = skewness[skewness > 0.02].index.tolist()
negative_skewness = skewness[skewness < -0.02].index.tolist()
zero_skewness = skewness[abs(skewness) <= 0.02].index.tolist()

print("Number of columns with positive skewness:", len(positive_skewness))
print("Number of columns with negative skewness:", len(negative_skewness))
print("Number of columns with zero skewness:", len(zero_skewness))
print(skewness)
# Out:
# Number of columns with positive skewness: 100
# Number of columns with negative skewness: 72
# Number of columns with zero skewness: 29
# target     2.657642
# var_0      0.235639
# var_1      0.053115
# var_2      0.260313
# var_3     -0.003548
# var_4     -0.048210
# var_5     -0.002038
# var_6      0.149476
# var_7      0.084598
# var_8     -0.104643
# var_9     -0.175433
# var_10    -0.056716
# var_11     0.070549
# var_12    -0.143664
# var_13    -0.176897
# var_14     0.038347
# var_15     0.035511
# var_16     0.191968
# var_17    -0.053671
# var_18     0.088625
# var_19     0.050517
# var_20     0.059918
# var_21    -0.001675
# var_22     0.156611
# var_23     0.062952
# var_24     0.142217
# var_25     0.175815
# var_26     0.172770
# var_27     0.020910
# var_28    -0.041626
# var_29     0.200364
# var_30    -0.113247
# var_31     0.074745
# var_32     0.003091
# var_33     0.089406
# var_34    -0.029669
# var_35    -0.021304
# var_36    -0.049432
# var_37     0.043867
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.decomposition import PCA
from kerastuner.tuners import RandomSearch

x = df.drop('target',axis = 1)
y = df['target']
scaler = StandardScaler()
scaled_x = scaler.fit_transform(x)
X_train, X_val, y_train, y_val = train_test_split(scaled_x, y, test_size=0.2, random_state=42)
# pca = PCA(n_components=0.95)  # Keep 95% of the variance
# X_train_pca = pca.fit_transform(X_train)
# X_val_pca = pca.transform(X_val)

model = keras.Sequential([
keras.layers.Dense(256, input_dim = X_train.shape[1], activation='relu'),
# keras.layers.BatchNormalization(),
keras.layers.Dense(128, activation='relu'),
keras.layers.Dense(64, activation='relu'),
keras.layers.Dense(64, activation='sigmoid'), 
# keras.layers.BatchNormalization(),
keras.layers.Dense(1, activation='sigmoid')

])
# Out:
# /opt/homebrew/anaconda3/envs/amulya_base/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 256)            │        51,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# ...

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32
)
# Out:
# Epoch 1/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 790us/step - accuracy: 0.9066 - loss: 0.2559
# Epoch 2/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 777us/step - accuracy: 0.9155 - loss: 0.2269
# Epoch 3/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 792us/step - accuracy: 0.9192 - loss: 0.2182
# Epoch 4/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 771us/step - accuracy: 0.9255 - loss: 0.2025
# Epoch 5/5
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 4s 769us/step - accuracy: 0.9355 - loss: 0.1788

# %%
model.evaluate(X_val,y_val)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.9046 - loss: 0.2680
# [0.26536986231803894, 0.9064249992370605]

# %% [markdown]
# without applying pca : test accuracy - 90
# train : 92
# with pca - same results
# by incresing number of number of neurons - same
# here as we are incresing no of epochs - overfitting
