# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
house_data = pd.read_csv("/users/amulya/Downloads/HousePricePrediction.csv")
# print(house_data.to_string())
# filtered_data = house_data.dropna(subset=['LotArea'])
saleprice_values = house_data['LotArea'].values
print(saleprice_values)
mean_saleprice = filtered_data['LotArea'].mean()
print(mean_saleprice)
median = filtered_data['LotArea'].median()   
std_saleprice = filtered_data['LotArea'].std(ddof = 0)
print(median)
x = np.linspace(mean_saleprice - 3*std_saleprice, mean_saleprice + 3*std_saleprice, 100)
y = (1/(std_saleprice * np.sqrt(2*np.pi))) * np.exp(-(x-mean_saleprice)**2 / (2*std_saleprice**2))
# Plot the histogram of SalePrice
plt.hist(saleprice_values, bins=30, density=True, alpha=0.6, color='g', label='LotArea Histogram')

plt.xlabel('values')
plt.ylabel('LotArea') 

plt.axvline(mean_saleprice, color='gray', linestyle='--', label='mean Line')
plt.axvline(median, color = 'yellow', linestyle='--', label='meadian Line')
plt.legend()
# Show the plot
plt.show()
# Out:
# [ 8450  9600 11250 ... 20000 10441  9627]
# 10169.563056888279
# 9455.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
house_data = pd.read_csv("/users/amulya/Downloads/HousePricePrediction.csv")
# print(house_data.to_string())
# filtered_data = house_data.dropna(subset=['LotArea'])
saleprice_values = house_data['YearBuilt'].values
print(saleprice_values)
mean_saleprice = filtered_data['YearBuilt'].mean()
print(mean_saleprice)
median = filtered_data['YearBuilt'].median() 
std_saleprice = filtered_data['YearBuilt'].std(ddof = 0)
print(median)
x = np.linspace(mean_saleprice - 3*std_saleprice, mean_saleprice + 3*std_saleprice, 100)
y = (1/(std_saleprice * np.sqrt(2*np.pi))) * np.exp(-(x-mean_saleprice)**2 / (2*std_saleprice**2))
# Plot the histogram of SalePrice
plt.hist(saleprice_values, bins=30, density=True, alpha=0.6, color='g', label='YearBuilt Histogram')

plt.xlabel('values')
plt.ylabel('YearBuilt') 

plt.axvline(mean_saleprice, color='gray', linestyle='--', label='mean Line')
plt.axvline(median, color = 'yellow', linestyle='--', label='meadian Line')
plt.legend()
# Show the plot
plt.show()
# Out:
# [2003 1976 2001 ... 1960 1992 1993]
# 1971.3214530500343
# 1973.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
house_data = pd.read_csv("/users/amulya/Downloads/HousePricePrediction.csv")
# print(house_data.to_string())
# filtered_data = house_data.dropna(subset=['LotArea'])
saleprice_values = house_data['OverallCond'].values
print(saleprice_values)
mean_saleprice = filtered_data['OverallCond'].mean()
print(mean_saleprice)
median = filtered_data['OverallCond'].median() 
std_saleprice = filtered_data['OverallCond'].std(ddof = 0)
print(median)
x = np.linspace(mean_saleprice - 3*std_saleprice, mean_saleprice + 3*std_saleprice, 100)
y = (1/(std_saleprice * np.sqrt(2*np.pi))) * np.exp(-(x-mean_saleprice)**2 / (2*std_saleprice**2))
# Plot the histogram of SalePrice
plt.hist(saleprice_values, bins=30, density=True, alpha=0.6, color='g', label='OverallCond Histogram')

plt.xlabel('values')
plt.ylabel('OverallCond') 

plt.axvline(mean_saleprice, color='gray', linestyle='--', label='mean Line')
plt.axvline(median, color = 'yellow', linestyle='--', label='meadian Line')
plt.legend()
# Show the plot
plt.show()
# Out:
# [5 8 5 ... 7 5 5]
# 5.564084989718985
# 5.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
house_data = pd.read_csv("/users/amulya/Downloads/HousePricePrediction.csv")
# print(house_data.to_string())
filtered_data = house_data.dropna(subset=['TotalBsmtSF'])
saleprice_values = filtered_data['TotalBsmtSF'].values
print(saleprice_values)
mean_saleprice = filtered_data['TotalBsmtSF'].mean()
print(mean_saleprice)
median = filtered_data['TotalBsmtSF'].median() 
std_saleprice = filtered_data['TotalBsmtSF'].std(ddof = 0)
print(median)
x = np.linspace(mean_saleprice - 3*std_saleprice, mean_saleprice + 3*std_saleprice, 100)
y = (1/(std_saleprice * np.sqrt(2*np.pi))) * np.exp(-(x-mean_saleprice)**2 / (2*std_saleprice**2))
# Plot the histogram of SalePrice
plt.hist(saleprice_values, bins=30, density=True, alpha=0.6, color='g', label='TotalBsmtSF Histogram')

plt.xlabel('values')
plt.ylabel('TotalBsmtSF') 

plt.axvline(mean_saleprice, color='gray', linestyle='--', label='mean Line')
plt.axvline(median, color = 'yellow', linestyle='--', label='meadian Line')
plt.legend()
# Show the plot
plt.show()
# Out:
# [ 856. 1262.  920. ... 1224.  912.  996.]
# 1051.7775873886224
# 989.5
