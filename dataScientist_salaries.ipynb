# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_csv('/users/amulya/Downloads/archive (10)/Glassdoor_Salary_Cleaned_Version.csv')
df.head(1)
df.columns
df.isna().sum()
# for col in df.columns:
#     filter_df = df[df[col] == '?']
#     print(len(filter_df))
df['Salary Estimate'].value_counts()
# df = df
# df['Salary Estimate'] = df['Salary Estimate'].str.replace("$", "").str.replace("K", "")
# salaries = df['Salary Estimate'].str.split("-", expand=True)

# # Convert salary columns to integers
# salary1 = salaries[0].astype(int)
# salary2 = salaries[1].astype(int)
# print(salary1)
df['Salary Estimate']
# df['Min Salary']
# Out:
# 0                     $53K-$91K (Glassdoor est.)
# 1                    $63K-$112K (Glassdoor est.)
# 2                     $80K-$90K (Glassdoor est.)
# 3                     $56K-$97K (Glassdoor est.)
# 4                    $86K-$143K (Glassdoor est.)
# 5                    $71K-$119K (Glassdoor est.)
# 6                     $54K-$93K (Glassdoor est.)
# 7                    $86K-$142K (Glassdoor est.)
# 8                     $38K-$84K (Glassdoor est.)
# 9                   $120K-$160K (Glassdoor est.)
# 10                  $126K-$201K (Glassdoor est.)
# 11                   $64K-$106K (Glassdoor est.)
# 12                  $106K-$172K (Glassdoor est.)
# 13                    $46K-$85K (Glassdoor est.)
# 14                   $83K-$144K (Glassdoor est.)
# 15                  $102K-$190K (Glassdoor est.)
# 16                   $67K-$137K (Glassdoor est.)
# 17                  $118K-$189K (Glassdoor est.)
# 18                  $110K-$175K (Glassdoor est.)
# ...

# %% [markdown]
# salary estimate : I'm taking avg of low and high value
