"http://www.wizergos.com",
"http://www.salespanda.com",
"http://www.huddleup.ai",
"http://www.xmplar.in",
"http://www.trustt.com",
"http://www.bookingsocial.com",
"http://www.webmedy.com",
"http://www.itrosys.com",
"http://www.fego.in",
"http://www.enaviya.com",
"http://www.milople.com",
"http://www.litmusworld.com",
"http://www.explorex.co",
"http://www.easynow.app",
"http://www.schooldiary.me",
"http://www.sunsmartglobal.com",
"http://www.conductcrm.com",
"http://www.3ionetra.in",
"http://www.workbook.ai",
"http://www.leadshuttle.com",
"http://www.betterplaceweb.com",
"http://www.clinchpad.com",
"http://www.userjoy.co",
"http://www.recooty.com",
"http://www.lancify.net",
"http://www.noticeboard.tech",
"http://www.dancingnumbers.com",
"http://www.cloudyogi.com",
"http://www.mogocrm.com",
"http://www.solidperformers.com",
"http://www.uptrixconsulting.com",
"http://www.24sevencommerce.com",
"http://www.indusface.com",
"http://www.digio.in",
"http://www.tenupsoft.com",
"http://www.hotify.ai",
"http://www.texperia.com",
"http://www.couture.ai",
"http://www.avenuegrowth.com",
"http://www.quartoerp.com",
"http://www.fraxinusit.com",
"http://www.focusro.com",
"http://www.navfarm.com",
"http://www.aarvitechnology.com",
"http://www.iberissoftware.com",
"http://www.mevvit.com",
"http://www.izooto.com",
"http://www.effitrac.com",
"http://www.aarogya.ai"
]
successful_links = []
titles = []
session = requests.Session()
session.max_redirects = 100 
for link in website_links:
    try:
        # page = requests.get(link)
        page = session.get(link)
        if page.status_code == 200:  # Check if the request was successful
            soup = BeautifulSoup(page.content)
            page_title = soup.title.text if soup.title else "No title found"
            
            successful_links.append(link)
            titles.append(page_title)
            # print("Page Title:", page_title)
            # You can extract other information from the page as needed
        else:
            # print(f"Failed to retrieve {link} Status code:", page.status_code)
            pass
    except (requests.exceptions.ConnectionError, requests.exceptions.InvalidURL) as e:
        # print(f"Failed to retrieve {link}: {e}")
        pass
print(successful_links)
data = {'Link': successful_links, 'Title': titles}
df = pd.DataFrame(data)

# Write the DataFrame to a CSV file
df.to_csv('/users/amulya/Desktop/csv_files/TAM.csv', index=False)
print('dshjbcdcbn')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 # website_links = ['https://www.incentius.com','https://www.frugaltesting.com','https://intellifysolutions.com']
# ----> 5 df = pd.read_excel('/users/amulya/Downloads/TAM.xlsx')
#       7 website_links = [
#       8 "http://www.incentius.com",
#       9 "http://www.intellifysolutions.com",
#    (...)
#     304 "http://www.aarogya.ai"
#     305 ]
#     306 successful_links = []
#
# ...

# %%
session = requests.Session()
page = requests.get('http://www.incentius.com')
soup = BeautifulSoup(page.content)
page_title = soup.title.text
print(page_title)
# Out:
# Home - Incentius - Enable Digital Transformation

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# website_links = ['https://www.incentius.com','https://www.frugaltesting.com','https://intellifysolutions.com']
df = pd.read_excel('/users/amulya/Downloads/TAM.xlsx')
df = df['Website']
# print(df)
successful_links = []
session = requests.Session()
session.max_redirects = 5 
for link in df:
    try:
        page = requests.get(link,allow_redirects=True)
        if page.status_code == 200:  # Check if the request was successful
            soup = BeautifulSoup(page.content)
            # Extract the page title
            # print(soup)
            # print('=====================')
            page_title = soup.title.text if soup.title else "No title found"
            successful_links.append(link)
            # print("Page Title:", page_title)
            # You can extract other information from the page as needed
        else:
            print(f"Failed to retrieve {link} Status code:", page.status_code)
    except (requests.exceptions.ConnectionError, requests.exceptions.InvalidURL) as e:
        print(f"Failed to retrieve {link}: {e}")
print(successful_links,'fetched links')
